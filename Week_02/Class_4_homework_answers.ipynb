# %% [markdown]
# # Class 4 homework: More practise with re-shaping dataframes

# %% [markdown]
# Let's look at a few more datasets. These will give you a bit more practice using some of the functions you have learned over the last few classes. These are tricky, and we are deliberately providing only sparse instructions so that you can challenge yourself. Work together if you can, and remember that in class you can ask the demonstrators for help if you need.

# %% [markdown]
# ## Load the modules
#
# First, let's import pandas and seaborn.

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## A dataset on bird nests in Greenland
#
# This dataset includes information on nesting sites, the number of nests assessed at each site, and the number of chicks found in each nest (calculated as a frequency across five different levels).
#
# First, read in `Greenland_nests.csv` from the Datasets folder. Then look at the dataset to make sure it has loaded correctly.

# %%
df = pd.read_csv('../Datasets/Greenland_nests.csv')

# %%
df
# Out:
#        Nesting Site  0 chicks  1 chick  2 chicks  3 chicks   >3 chicks  \
# 0            Qaanaq      0.21     0.00      0.57       0.22       0.00
# 1          Sisimiut      0.00     0.34      0.65       0.01       0.00
# 2         Maniitsoq      0.00     0.22      0.56       0.17       0.05
# 3          Tasiilaq      0.34     0.45      0.12       0.09       0.00
# 4  Ittoqqortoormiit      0.44     0.25      0.31       0.00       0.00
# 5              Nuuk      0.02     0.57      0.23       0.13       0.05
# 6         Disko Bay      0.11     0.42      0.24       0.23       0.00
#
#    Nests assessed
# 0             356
# 1             523
# 2            2113
# 3              67
# 4             266
# 5             734
# 6             225

# %% [markdown]
# Now try melting this dataset into long form. Call your variable name 'No_chicks' and your value name 'Frequency'. Hint: your values are contained within the '0 chicks', '1 chick', '2 chicks', '3 chicks ' and '>3 chicks' columns.

# %%
df_melt = pd.melt(df, id_vars = ['Nesting Site', 'Nests assessed'],
                  value_vars = ['0 chicks', '1 chick', '2 chicks', '3 chicks ', '>3 chicks'], # note the space in '3 chicks '
                  var_name = 'No_chicks',
                  value_name = 'Frequency')

# %%
df_melt
# Out:
#         Nesting Site  Nests assessed  No_chicks  Frequency
# 0             Qaanaq             356   0 chicks       0.21
# 1           Sisimiut             523   0 chicks       0.00
# 2          Maniitsoq            2113   0 chicks       0.00
# 3           Tasiilaq              67   0 chicks       0.34
# 4   Ittoqqortoormiit             266   0 chicks       0.44
# 5               Nuuk             734   0 chicks       0.02
# 6          Disko Bay             225   0 chicks       0.11
# 7             Qaanaq             356    1 chick       0.00
# 8           Sisimiut             523    1 chick       0.34
# 9          Maniitsoq            2113    1 chick       0.22
# 10          Tasiilaq              67    1 chick       0.45
# 11  Ittoqqortoormiit             266    1 chick       0.25
# 12              Nuuk             734    1 chick       0.57
# 13         Disko Bay             225    1 chick       0.42
# 14            Qaanaq             356   2 chicks       0.57
# 15          Sisimiut             523   2 chicks       0.65
# 16         Maniitsoq            2113   2 chicks       0.56
# 17          Tasiilaq              67   2 chicks       0.12
# 18  Ittoqqortoormiit             266   2 chicks       0.31
# 19              Nuuk             734   2 chicks       0.23
# 20         Disko Bay             225   2 chicks       0.24
# 21            Qaanaq             356  3 chicks        0.22
# 22          Sisimiut             523  3 chicks        0.01
# 23         Maniitsoq            2113  3 chicks        0.17
# 24          Tasiilaq              67  3 chicks        0.09
# 25  Ittoqqortoormiit             266  3 chicks        0.00
# 26              Nuuk             734  3 chicks        0.13
# 27         Disko Bay             225  3 chicks        0.23
# 28            Qaanaq             356  >3 chicks       0.00
# 29          Sisimiut             523  >3 chicks       0.00
# 30         Maniitsoq            2113  >3 chicks       0.05
# 31          Tasiilaq              67  >3 chicks       0.00
# 32  Ittoqqortoormiit             266  >3 chicks       0.00
# 33              Nuuk             734  >3 chicks       0.05
# 34         Disko Bay             225  >3 chicks       0.00

# %% [markdown]
# Now have a go plotting these data using the following code `sns.stripplot(x = 'No_chicks', y = 'Frequency', hue = 'Nesting Site', data = df_melt);`. You might need to edit this depending on what you called your dataframe.

# %%
sns.stripplot(x = 'No_chicks', y = 'Frequency', hue = 'Nesting Site', data = df_melt);

# %% [markdown]
# ADD STATISTICAL SUMMARY Q here?

# %% [markdown]
# # A dataset on plant locations
#
# This dataset contains location information for the plant *Begonia conchifolia*.
#
# Read in the B_conch_loc.csv file from the Datasets folder. Check to make sure it has loaded correctly.

# %%
df = pd.read_csv('../Datasets/B_conch_loc.csv')

# %%
df.head()
# Out:
#    Begonia conchifolia  Costa Rica     Liberia  10.630573, -85.439346  \
# 0  Begonia conchifolia  Costa Rica    San José   9.934739, -84.087502
# 1  Begonia conchifolia  Costa Rica    Alajuela  10.582930, -84.261923
# 2  Begonia conchifolia  Costa Rica     Cartago   9.588293, -85.296503
# 3  Begonia conchifolia  Costa Rica  Guanacaste   9.629001, -84.929014
# 4  Begonia conchifolia  Costa Rica     Heredia  10.113520, -85.166314
#
#   Davidse, G., M. Sousa Sánchez, S. Knapp & F. Chiang Cabrera  2015  \
# 0  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...           2015
# 1                                     Burt-Utley, K.           1985
# 2                                     Burt-Utley, K.           1985
# 3                                     Burt-Utley, K.           1985
# 4                                     Burt-Utley, K.           1985
#
#                         Saururaceae a Zygophyllaceae            Fl. Mesoamer.  \
# 0                       Saururaceae a Zygophyllaceae            Fl. Mesoamer.
# 1  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
# 2  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
# 3  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
# 4  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
#
#    2(3): v–xvii, 1–347
# 0  2(3): v–xvii, 1–347
# 1         25(1): 1–131
# 2         25(1): 1–131
# 3         25(1): 1–131
# 4         25(1): 1–131

# %% [markdown]
# &nbsp;
# <div>
# <img src="attachment:begonia-7875959_640.jpg" width='50%' title=""/>
# </div>
# &nbsp;
#
# Unfortunately, this dataset hasn't loaded in correctly as the first row has been used as the column headers. Try again, this time including `header = None` in your code. Then use `df.head()` to see what it looks like.

# %%
df = pd.read_csv('../Datasets/B_conch_loc.csv', header = None)

# %%
df.head()
# Out:
#                      0           1           2                      3  \
# 0  Begonia conchifolia  Costa Rica     Liberia  10.630573, -85.439346
# 1  Begonia conchifolia  Costa Rica    San José   9.934739, -84.087502
# 2  Begonia conchifolia  Costa Rica    Alajuela  10.582930, -84.261923
# 3  Begonia conchifolia  Costa Rica     Cartago   9.588293, -85.296503
# 4  Begonia conchifolia  Costa Rica  Guanacaste   9.629001, -84.929014
#
#                                                    4     5  \
# 0  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...  2015
# 1  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...  2015
# 2                                     Burt-Utley, K.  1985
# 3                                     Burt-Utley, K.  1985
# 4                                     Burt-Utley, K.  1985
#
#                                                    6                        7  \
# 0                       Saururaceae a Zygophyllaceae            Fl. Mesoamer.
# 1                       Saururaceae a Zygophyllaceae            Fl. Mesoamer.
# 2  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
# 3  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
# 4  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
#
#                      8
# 0  2(3): v–xvii, 1–347
# 1  2(3): v–xvii, 1–347
# 2         25(1): 1–131
# 3         25(1): 1–131
# 4         25(1): 1–131

# %% [markdown]
# Check the data types of each variable.

# %%
df.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5     int64
# 6    object
# 7    object
# 8    object
# dtype: object

# %% [markdown]
# Now let's try and tidy it up a little. First, make a new column called 'Reference' which concatenates all the information from columns 4 - 8. Remember, you will need to use the code `.astype(str)` if the variables are not coded as strings.

# %%
df['Reference'] = df[4].astype(str) + '_' + df[5].astype(str) + '_' + df[6].astype(str) + '_' + df[7].astype(str) + '_' + df[8].astype(str)
df.head()
# Out:
#                      0           1           2                      3  \
# 0  Begonia conchifolia  Costa Rica     Liberia  10.630573, -85.439346
# 1  Begonia conchifolia  Costa Rica    San José   9.934739, -84.087502
# 2  Begonia conchifolia  Costa Rica    Alajuela  10.582930, -84.261923
# 3  Begonia conchifolia  Costa Rica     Cartago   9.588293, -85.296503
# 4  Begonia conchifolia  Costa Rica  Guanacaste   9.629001, -84.929014
#
#                                                    4     5  \
# 0  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...  2015
# 1  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...  2015
# 2                                     Burt-Utley, K.  1985
# 3                                     Burt-Utley, K.  1985
# 4                                     Burt-Utley, K.  1985
#
#                                                    6                        7  \
# 0                       Saururaceae a Zygophyllaceae            Fl. Mesoamer.
# 1                       Saururaceae a Zygophyllaceae            Fl. Mesoamer.
# 2  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
# 3  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
# 4  A revision of Central American species of Bego...  Tulane Stud. Zool. Bot.
#
#                      8                                          Reference
# 0  2(3): v–xvii, 1–347  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...
# 1  2(3): v–xvii, 1–347  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...
# 2         25(1): 1–131  Burt-Utley, K._1985_A revision of Central Amer...
# 3         25(1): 1–131  Burt-Utley, K._1985_A revision of Central Amer...
# 4         25(1): 1–131  Burt-Utley, K._1985_A revision of Central Amer...

# %% [markdown]
# Now drop columns 4 - 8 as we don't need them any more.

# %%
df = df.drop(columns = [4, 5, 6, 7, 8])
df.head()
# Out:
#                      0           1           2                      3  \
# 0  Begonia conchifolia  Costa Rica     Liberia  10.630573, -85.439346
# 1  Begonia conchifolia  Costa Rica    San José   9.934739, -84.087502
# 2  Begonia conchifolia  Costa Rica    Alajuela  10.582930, -84.261923
# 3  Begonia conchifolia  Costa Rica     Cartago   9.588293, -85.296503
# 4  Begonia conchifolia  Costa Rica  Guanacaste   9.629001, -84.929014
#
#                                            Reference
# 0  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...
# 1  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...
# 2  Burt-Utley, K._1985_A revision of Central Amer...
# 3  Burt-Utley, K._1985_A revision of Central Amer...
# 4  Burt-Utley, K._1985_A revision of Central Amer...

# %% [markdown]
# Now let's split column 3 into longitude and latitude. Use `str.split` to split this column and form two new columns called Longitude and Latitude. Note that the separator is ', ' this time.

# %%
df[['Longitude', 'Latitude']] = df[3].str.split(', ', expand = True)
df.head()
# Out:
#                      0           1           2                      3  \
# 0  Begonia conchifolia  Costa Rica     Liberia  10.630573, -85.439346
# 1  Begonia conchifolia  Costa Rica    San José   9.934739, -84.087502
# 2  Begonia conchifolia  Costa Rica    Alajuela  10.582930, -84.261923
# 3  Begonia conchifolia  Costa Rica     Cartago   9.588293, -85.296503
# 4  Begonia conchifolia  Costa Rica  Guanacaste   9.629001, -84.929014
#
#                                            Reference  Longitude    Latitude
# 0  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...  10.630573  -85.439346
# 1  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...   9.934739  -84.087502
# 2  Burt-Utley, K._1985_A revision of Central Amer...  10.582930  -84.261923
# 3  Burt-Utley, K._1985_A revision of Central Amer...   9.588293  -85.296503
# 4  Burt-Utley, K._1985_A revision of Central Amer...   9.629001  -84.929014

# %% [markdown]
# Now drop column 3.

# %%
df = df.drop(columns = 3)
df.head()
# Out:
#                      0           1           2  \
# 0  Begonia conchifolia  Costa Rica     Liberia
# 1  Begonia conchifolia  Costa Rica    San José
# 2  Begonia conchifolia  Costa Rica    Alajuela
# 3  Begonia conchifolia  Costa Rica     Cartago
# 4  Begonia conchifolia  Costa Rica  Guanacaste
#
#                                            Reference  Longitude    Latitude
# 0  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...  10.630573  -85.439346
# 1  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...   9.934739  -84.087502
# 2  Burt-Utley, K._1985_A revision of Central Amer...  10.582930  -84.261923
# 3  Burt-Utley, K._1985_A revision of Central Amer...   9.588293  -85.296503
# 4  Burt-Utley, K._1985_A revision of Central Amer...   9.629001  -84.929014

# %% [markdown]
# And finally, rename the columns using `['Species_name', 'Country', 'Location', 'Reference', 'Longitude', 'Latitude']`.

# %%
df.columns = ['Species_name', 'Country', 'Location', 'Reference', 'Longitude', 'Latitude']
df.head()
# Out:
#           Species_name     Country    Location  \
# 0  Begonia conchifolia  Costa Rica     Liberia
# 1  Begonia conchifolia  Costa Rica    San José
# 2  Begonia conchifolia  Costa Rica    Alajuela
# 3  Begonia conchifolia  Costa Rica     Cartago
# 4  Begonia conchifolia  Costa Rica  Guanacaste
#
#                                            Reference  Longitude    Latitude
# 0  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...  10.630573  -85.439346
# 1  Davidse, G., M. Sousa Sánchez, S. Knapp & F. C...   9.934739  -84.087502
# 2  Burt-Utley, K._1985_A revision of Central Amer...  10.582930  -84.261923
# 3  Burt-Utley, K._1985_A revision of Central Amer...   9.588293  -85.296503
# 4  Burt-Utley, K._1985_A revision of Central Amer...   9.629001  -84.929014

# %% [markdown]
# Now you can stand back and admire your lovely tidy dataset!

# %% [markdown]
# ## If you have more time...
#
# Spend some time this week going over all the material we have covered so far. Are there any functions that you don't understand? Have a go playing with these on some other datasets. And if you haven't already, start putting together your own cheat sheet of useful functions.
